# %%
#https://gist.github.com/yanofsky/5436496
#!/usr/bin/env python
# encoding: utf-8
#https://github.com/tweepy/tweepy

import tweepy
import csv
from tweepy import OAuthHandler, Stream, StreamListener

#Twitter API credentials
consumer_key = "I0E7xGaPsVIIyg0sq8tfw"
consumer_secret = "frk7rjhTVHEuRErf4V2h93xZ6eSAr2myy9gH4RaU"
access_key = "228245421-FPyC4SFufgkHDmHy7gTpEqm36mbFepYmkQ2p54xf"
access_secret = "cYc2xsbeKiTAlb8RuQ9btHZxERGNoFrlazKBPTnQ"

# %%
def get_all_tweets(screen_name): 
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    alltweets = []

    new_tweets = api.user_timeline(screen_name = screen_name,count=200, tweet_mode="extended")

    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        print("getting tweets before %s" % (oldest))
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest, tweet_mode="extended")
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
        print("...%s tweets downloaded so far" % (len(alltweets)))

    outtweets = [[tweet.id_str, tweet.created_at, tweet.full_text.encode("utf-8")] for tweet in alltweets]
    with open('all_tweets/%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    pass

# %%
if __name__ == '__main__':
    
    idn = open('account_list/tw-acc-id.txt')
    jv = open('account_list/tw-acc-jv.txt')
    sd = open('account_list/tw-acc-sd.txt')

    #for line in jv:
     #   get_all_tweets(line)

    for line in sd:
        get_all_tweets(line)
# Out:
# getting tweets before 1187354777543307263
# ...400 tweets downloaded so far
# getting tweets before 980367939986636800
# ...600 tweets downloaded so far
# getting tweets before 860149740175933440
# ...800 tweets downloaded so far
# getting tweets before 777013138986151935
# ...1000 tweets downloaded so far
# getting tweets before 734233680315482113
# ...1200 tweets downloaded so far
# getting tweets before 675960789086380031
# ...1400 tweets downloaded so far
# getting tweets before 626258340402761727
# ...1600 tweets downloaded so far
# getting tweets before 591123741800800255
# ...1800 tweets downloaded so far
# getting tweets before 568743283649859583
# ...2000 tweets downloaded so far
# getting tweets before 534560019917049856
# ...2200 tweets downloaded so far
# getting tweets before 491356009269825535
# ...2291 tweets downloaded so far
# getting tweets before 327664483264770047
# ...2291 tweets downloaded so far
# getting tweets before 578490042206674943
# ...

# %%
get_all_tweets('@tweetkuwagu')
# Out:
# getting tweets before 1264689795655061503
# ...400 tweets downloaded so far
# getting tweets before 1248844123278360582
# ...600 tweets downloaded so far
# getting tweets before 1243882652865683455
# ...798 tweets downloaded so far
# getting tweets before 1230492520204816383
# ...998 tweets downloaded so far
# getting tweets before 1203909051723075584
# ...1198 tweets downloaded so far
# getting tweets before 1165192264055812095
# ...1398 tweets downloaded so far
# getting tweets before 1128295879096430591
# ...1598 tweets downloaded so far
# getting tweets before 1101718566624059391
# ...1798 tweets downloaded so far
# getting tweets before 1066686886586966015
# ...1996 tweets downloaded so far
# getting tweets before 818261514461188096
# ...2196 tweets downloaded so far
# getting tweets before 730696413336633345
# ...2396 tweets downloaded so far
# getting tweets before 583551398307962879
# ...2419 tweets downloaded so far
# getting tweets before 542721439879528447
# ...

# %%
get_all_tweets('@curuk_nyeceub')
# Out:
# getting tweets before 1229355244871544832
# ...400 tweets downloaded so far
# getting tweets before 1153633309487878143
# ...600 tweets downloaded so far
# getting tweets before 1119502484295172095
# ...800 tweets downloaded so far
# getting tweets before 1107234894646657023
# ...1000 tweets downloaded so far
# getting tweets before 1086877965365858304
# ...1199 tweets downloaded so far
# getting tweets before 1077620941230723071
# ...1399 tweets downloaded so far
# getting tweets before 1072475712685334528
# ...1598 tweets downloaded so far
# getting tweets before 1022848258329071615
# ...1797 tweets downloaded so far
# getting tweets before 995997243919355904
# ...1997 tweets downloaded so far
# getting tweets before 968464546217189375
# ...2196 tweets downloaded so far
# getting tweets before 949677655393148927
# ...2394 tweets downloaded so far
# getting tweets before 935081927953887238
# ...2594 tweets downloaded so far
# getting tweets before 928275211803279359
# ...

# %%
get_all_tweets('@EusiHateAing')
# Out:
# getting tweets before 1267415421629546495
# ...400 tweets downloaded so far
# getting tweets before 1102609453034102783
# ...599 tweets downloaded so far
# getting tweets before 1043133614890790912
# ...799 tweets downloaded so far
# getting tweets before 1009583537773658112
# ...999 tweets downloaded so far
# getting tweets before 974637885050667007
# ...1196 tweets downloaded so far
# getting tweets before 955449796545794047
# ...1395 tweets downloaded so far
# getting tweets before 942330067014655999
# ...1595 tweets downloaded so far
# getting tweets before 926351489718657026
# ...1785 tweets downloaded so far
# getting tweets before 906862409150636032
# ...1982 tweets downloaded so far
# getting tweets before 885660427836768258
# ...2179 tweets downloaded so far
# getting tweets before 869413522341375999
# ...2377 tweets downloaded so far
# getting tweets before 860061881137995777
# ...2576 tweets downloaded so far
# getting tweets before 854927943901913087
# ...
